# %%
# Importando bibliotecas essenciais para ciência de dados
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Capítulo 01 - Começando com IPython e Jupyter

# %% [markdown]
# > **Neste Capítulo tem vários exemplos básicos de como consultar informações do seu código dentro do próprio Jupyter**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Acessando a documentação de uma função
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
# Acessando a documentação de uma função usando ?
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
# Exemplo com listas e o método insert
L = [1, 2, 3, 4, 5]
L.insert?
# Out:
# Signature: L.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
# Consultando a documentação
L?
# Out:
# Type:        list
# String form: [1, 2, 3, 4, 5]
# Length:      5
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
# Definindo uma função com docstring e acessando sua documentação
def square(x):
    """Returns the square of a number."""
    return x * x

square?
# Out:
# Signature: square(x)
# Docstring: Returns the square of a number.
# File:      c:\users\dione\appdata\local\temp\ipykernel_14668\777408048.py
# Type:      function
